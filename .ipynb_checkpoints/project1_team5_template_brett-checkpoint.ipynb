# %% [markdown]
# # Global Budget Spending Analysis
# ----
# <i> Project 1 Team 5 </i><br/>
# Brett Fuller, Diego Jones, Mav Sanchez

# %%
#Import necessary package dependencies
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
from pprint import pprint
from scipy.stats import linregress
from pandas import DataFrame


#Import API Key
from config import api_key

#Define directories
source_data_dir = "source_data"
staging_data_dir = "staging_data"
target_data_dir = "target_data"
target_images_dir = "target_images"

# %% [markdown]
# ### Data extraction
# ----
# #####            API Calls

# %%
# Define base URLs for API
base_url_fromwherever ="put main endpoint here"

# %%
# Get  data
list_whatever = []
save_to_whatever = []

for a in list_whatever:
    
    query_url = base_url_fromwherever + 'appid=' + api_key + '&param=' + a
    response = requests.get(query_url).json() 
    try:
        list_whatever.append(response) #customize depending on the JSON structure
    except:
        pass

# Save api data to data frames
staging_df = pd.DataFrame(list_whatever)

# %%
# Save df to csv so we don't have to perform API calls again
staging_df.to_csv(f"{staging_data_dir}/staging_df.csv")

# %%
#####            CSV Load

# %%
budget_breakdown = "source_data/budget_breakdown.csv"

budgetbreakdown_df = pd.read_csv(budget_breakdown)
clean_budgetbreakdown = budgetbreakdown_df[['Unnamed: 0', 'Expenditure on general public services',
       'Expenditure on defense', 'Expenditure on public order & safety',
       'Expenditure on economic affairs',
       'Expenditure on environment protection',
       'Expenditure on housing & community amenities', 'Expenditure on health',
       'Expenditure on recreation, culture, & religion',
       'Expenditure on education', 'Expenditure on social protection']]
clean_budgetbreakdown = clean_budgetbreakdown.dropna()

clean_budgetbreakdown = clean_budgetbreakdown.rename(columns = {'Unnamed: 0': 'Country'})

# %%
country_rank = "source_data/top_73.csv"
country_ranking = pd.read_csv(country_rank, header=None
                             )
country_ranking = country_ranking.rename(columns = {0: 'Country'})

combined_countrydf = clean_budgetbreakdown.merge(country_ranking, on='Country')
combined_countrydf.columns = ['Country',
               'Expenditure on general public services',
                               'Expenditure on defense',
                 'Expenditure on public order & safety',
                      'Expenditure on economic affairs',
                'Expenditure on environment protection',
         'Expenditure on housing & community amenities',
                                'Expenditure on health',
       'Expenditure on recreation, culture, & religion',
                             'Expenditure on education',
                     'Expenditure on social protection',
                                                      'Overall Ranking',
                                                      'Entrepreneurship Ranking',
                                                      'Adventure Ranking',
                                                      'Citizenship Ranking',
                                                      'Cultural Influence Ranking',
                                                      'Heritage Ranking',
                                                      'Movers Ranking',
                                                      'Open For Business Ranking',
                                                      'Power Ranking',
                                                     'Quality of Life Ranking']

combined_countrydf.head()
# Out:
#    Country  Expenditure on general public services  Expenditure on defense  \
# 0  Austria                                     6.4                     0.6
# 1  Estonia                                     4.0                     2.4
# 2  Finland                                     8.0                     1.3
# 3   France                                     6.2                     1.8
# 4  Germany                                     5.7                     0.9
#
#    Expenditure on public order & safety  Expenditure on economic affairs  \
# 0                                   1.3                              5.7
# 1                                   1.9                              4.2
# 2                                   1.2                              4.5
# 3                                   1.6                              5.5
# 4                                   1.6                              3.3
#
#    Expenditure on environment protection  \
# 0                                    0.4
# 1                                    0.6
# 2                                    0.2
# 3                                    0.9
# 4                                    0.6
#
#    Expenditure on housing & community amenities  Expenditure on health  \
# 0                                           0.3                    8.2
# 1                                           0.3                    5.2
# 2                                           0.3                    7.2
# 3                                           1.1                    8.1
# 4                                           0.4                    7.2
#
#    Expenditure on recreation, culture, & religion  Expenditure on education  \
# 0                                             1.2                       4.9
# 1                                             2.0                       5.7
# 2                                             1.4                       6.1
# 3                                             1.4                       5.5
# 4                                             1.0                       4.1
#
#    ...  Overall Ranking  Entrepreneurship Ranking  Adventure Ranking  \
# 0  ...               18                        17                 22
# 1  ...               55                        40                 60
# 2  ...               14                        16                 27
# 3  ...               12                        15                 12
# 4  ...                4                         1                 50
#
#    Citizenship Ranking  Cultural Influence Ranking  Heritage Ranking  \
# 0                   12                          25                20
# 1                   26                          61                62
# 2                    6                          26                43
# 3                   13                           2                 4
# 4                   10                          15                19
#
#    Movers Ranking  Open For Business Ranking  Power Ranking  \
# 0              59                         15             27
# 1              73                         26             72
# 2              32                          9             35
# 3              44                         29              6
# 4              41                         17              4
#
#    Quality of Life Ranking
# 0                       11
# 1                       45
# 2                        9
# 3                       16
# 4                       10
#
# [5 rows x 21 columns]

# %%
population_breakdown = "source_data/Countries.csv"

populationbreakdown_df = pd.read_csv(population_breakdown)
populationbreakdown_df.columns


doublecombined_countrydf = combined_countrydf.merge(populationbreakdown_df, on='Country')
doublecombined_countrydf.head()
# Out:
#    Country  Expenditure on general public services  Expenditure on defense  \
# 0  Austria                                     6.4                     0.6
# 1  Estonia                                     4.0                     2.4
# 2  Finland                                     8.0                     1.3
# 3   France                                     6.2                     1.8
# 4  Germany                                     5.7                     0.9
#
#    Expenditure on public order & safety  Expenditure on economic affairs  \
# 0                                   1.3                              5.7
# 1                                   1.9                              4.2
# 2                                   1.2                              4.5
# 3                                   1.6                              5.5
# 4                                   1.6                              3.3
#
#    Expenditure on environment protection  \
# 0                                    0.4
# 1                                    0.6
# 2                                    0.2
# 3                                    0.9
# 4                                    0.6
#
#    Expenditure on housing & community amenities  Expenditure on health  \
# 0                                           0.3                    8.2
# 1                                           0.3                    5.2
# 2                                           0.3                    7.2
# 3                                           1.1                    8.1
# 4                                           0.4                    7.2
#
#    Expenditure on recreation, culture, & religion  Expenditure on education  \
# 0                                             1.2                       4.9
# 1                                             2.0                       5.7
# 2                                             1.4                       6.1
# 3                                             1.4                       5.5
# 4                                             1.0                       4.1
#
#    ...  Movers Ranking  Open For Business Ranking  Power Ranking  \
# 0  ...              59                         15             27
# 1  ...              73                         26             72
# 2  ...              32                          9             35
# 3  ...              44                         29              6
# 4  ...              41                         17              4
#
#    Quality of Life Ranking  GDPPC  Literacy  InfantMortality  Agriculture  \
# 0                       11  43439     0.980              3.4        0.014
# 1                       45  17295     0.998              3.8        0.034
# 2                        9  41921     1.000              2.5        0.028
# 3                       16  36248     0.990              3.3        0.017
# 4                       10  41219     0.990              3.4        0.007
#
#    Population  NetMigration
# 0     8611000           5.2
# 1     1312000          -3.2
# 2     5482000           3.0
# 3    66810000           1.1
# 4    81410000           1.5
#
# [5 rows x 27 columns]

# %%
# Load raw CSV files to data frame
safety_rank_data = pd.read_csv(f"{source_data_dir}/safety.csv")
safety_rank_data.head()
# Out:
#    Rank      Country  Amount spent on Public Safety (in Billions)
# 0     1  Netherlands                                       193.40
# 1     2       Norway                                        89.84
# 2     3    Australia                                          NaN
# 3     4       Sweden                                          NaN
# 4     5       Canada                                          NaN

# %%
health_rank_data = pd.read_csv(f"{source_data_dir}/health.csv")
health_rank_data.head()
# Out:
#                 Country                           Indicator Name       2016  \
# 0  Hong Kong SAR, China  Life expectancy at birth, total (years)  84.226829
# 1                 Japan  Life expectancy at birth, total (years)  83.984878
# 2      Macao SAR, China  Life expectancy at birth, total (years)  83.854000
# 3           Switzerland  Life expectancy at birth, total (years)  83.602439
# 4                 Spain  Life expectancy at birth, total (years)  83.329268
#
#         2017
# 0  84.680488
# 1  84.099756
# 2  83.989000
# 3  83.602439
# 4  83.329268

# %% [markdown]
# ### Data cleansing
# ----

# %%
# Options
# Delete nulls
# FillNA with zero, etc
# Reformat data (date format, name format)
# Save only the columns you need
from pandas import DataFrame

# %%
health2016 = pd.merge(health_rank_data, doublecombined_countrydf, on="Country")
health2016
# Out:
#                  Country                           Indicator Name       2016  \
# 0                  Japan  Life expectancy at birth, total (years)  83.984878
# 1            Switzerland  Life expectancy at birth, total (years)  83.602439
# 2                  Spain  Life expectancy at birth, total (years)  83.329268
# 3                  Italy  Life expectancy at birth, total (years)  83.243902
# 4              Singapore  Life expectancy at birth, total (years)  82.846341
# 5             Luxembourg  Life expectancy at birth, total (years)  82.685366
# 6                 France  Life expectancy at birth, total (years)  82.524390
# 7              Australia  Life expectancy at birth, total (years)  82.448780
# 8                 Israel  Life expectancy at birth, total (years)  82.407317
# 9                 Norway  Life expectancy at birth, total (years)  82.407317
# 10                Sweden  Life expectancy at birth, total (years)  82.307317
# 11               Austria  Life expectancy at birth, total (years)  81.641463
# 12           New Zealand  Life expectancy at birth, total (years)  81.612439
# 13           Netherlands  Life expectancy at birth, total (years)  81.560976
# 14               Finland  Life expectancy at birth, total (years)  81.429268
# 15                Greece  Life expectancy at birth, total (years)  81.387805
# 16              Slovenia  Life expectancy at birth, total (years)  81.175610
# 17              Portugal  Life expectancy at birth, total (years)  81.124390
# 18               Germany  Life expectancy at birth, total (years)  80.990244
# 19               Denmark  Life expectancy at birth, total (years)  80.853659
# 20        Czech Republic  Life expectancy at birth, total (years)  79.026829
# 21         United States  Life expectancy at birth, total (years)  78.539024
# 22               Croatia  Life expectancy at birth, total (years)  78.021951
# 23                Poland  Life expectancy at birth, total (years)  77.851220
# 24               Estonia  Life expectancy at birth, total (years)  77.641463
# 25  United Arab Emirates  Life expectancy at birth, total (years)  77.470000
# 26                Turkey  Life expectancy at birth, total (years)  76.860000
# 27              Thailand  Life expectancy at birth, total (years)  76.403000
# 28               Romania  Life expectancy at birth, total (years)  75.309756
# 29              Bulgaria  Life expectancy at birth, total (years)  74.812195
# 30             Lithuania  Life expectancy at birth, total (years)  74.670732
# 31                Latvia  Life expectancy at birth, total (years)  74.580488
# 32               Belarus  Life expectancy at birth, total (years)  73.826829
# 33            Azerbaijan  Life expectancy at birth, total (years)  72.493000
# 34            Kazakhstan  Life expectancy at birth, total (years)  72.300000
# 35               Ukraine  Life expectancy at birth, total (years)  71.476341
# 36             Indonesia  Life expectancy at birth, total (years)  71.035000
# 37          South Africa  Life expectancy at birth, total (years)  63.153000
#
#          2017  Expenditure on general public services  Expenditure on defense  \
# 0   84.099756                                     3.9                     0.9
# 1   83.602439                                     4.7                     0.8
# 2   83.329268                                     5.8                     1.0
# 3   83.243902                                     7.9                     1.3
# 4   82.895122                                     1.0                     3.3
# 5   82.685366                                     5.0                     0.4
# 6   82.524390                                     6.2                     1.8
# 7   82.497561                                     4.2                     1.9
# 8   82.602439                                     3.6                     5.7
# 9   82.509756                                     4.7                     1.6
# 10  82.307317                                     6.7                     1.2
# 11  81.641463                                     6.4                     0.6
# 12  81.658537                                     4.2                     0.9
# 13  81.560976                                     4.5                     1.1
# 14  81.429268                                     8.0                     1.3
# 15  81.387805                                     8.8                     2.1
# 16  81.175610                                     6.6                     0.9
# 17  81.124390                                     8.3                     0.9
# 18  80.990244                                     5.7                     0.9
# 19  81.004878                                     6.3                     1.1
# 20  79.475610                                     4.2                     0.7
# 21  78.539024                                     5.7                     3.2
# 22  77.826829                                     8.1                     1.1
# 23  77.851220                                     4.7                     1.6
# 24  77.641463                                     4.0                     2.4
# 25  77.647000                                    14.3                     0.8
# 26  77.161000                                     4.8                     1.4
# 27  76.683000                                     7.6                     1.4
# 28  75.309756                                     4.4                     1.7
# 29  74.812195                                     2.8                     1.1
# 30  74.670732                                     4.0                     1.6
# 31  74.680488                                     4.4                     1.6
# 32  74.129268                                     3.4                     1.2
# 33  72.693000                                     4.4                     3.5
# 34  72.950000                                     1.7                     1.4
# 35  71.780976                                     5.6                     2.5
# 36  71.282000                                     3.8                     1.1
# 37  63.538000                                    23.7                     1.2
#
#     Expenditure on public order & safety  Expenditure on economic affairs  \
# 0                                    1.2                              3.5
# 1                                    1.6                              4.0
# 2                                    1.9                              3.7
# 3                                    1.9                              3.9
# 4                                    1.0                              2.7
# 5                                    1.0                              5.7
# 6                                    1.6                              5.5
# 7                                    1.7                              4.0
# 8                                    1.6                              2.2
# 9                                    1.2                              5.4
# 10                                   1.3                              4.2
# 11                                   1.3                              5.7
# 12                                   1.9                              3.0
# 13                                   1.9                              3.9
# 14                                   1.2                              4.5
# 15                                   2.1                              4.1
# 16                                   1.7                              4.6
# 17                                   1.8                              3.2
# 18                                   1.6                              3.3
# 19                                   1.0                              3.3
# 20                                   1.7                              5.9
# 21                                   2.0                              3.4
# 22                                   2.3                              5.9
# 23                                   2.2                              4.4
# 24                                   1.9                              4.2
# 25                                   3.6                              4.9
# 26                                   2.1                              4.1
# 27                                   1.2                              2.3
# 28                                   2.0                              4.8
# 29                                   2.4                              4.1
# 30                                   1.5                              3.0
# 31                                   2.2                              4.7
# 32                                   1.9                              5.0
# 33                                   2.1                              8.8
# 34                                   1.0                              1.7
# 35                                   3.0                              2.5
# 36                                   1.3                              2.3
# 37                                   3.7                              6.6
#
#     Expenditure on environment protection  \
# 0                                     1.2
# 1                                     0.6
# 2                                     0.8
# 3                                     0.9
# 4                                     0.2
# 5                                     0.8
# 6                                     0.9
# 7                                     0.8
# 8                                     0.6
# 9                                     0.9
# 10                                    0.4
# 11                                    0.4
# 12                                    0.9
# 13                                    1.4
# 14                                    0.2
# 15                                    1.4
# 16                                    0.6
# 17                                    0.6
# 18                                    0.6
# 19                                    0.4
# 20                                    0.7
# 21                                    0.0
# 22                                    0.6
# 23                                    0.4
# 24                                    0.6
# 25                                    0.7
# 26                                    0.4
# 27                                    0.0
# 28                                    0.6
# 29                                    0.6
# 30                                    0.5
# 31                                    0.5
# 32                                    0.1
# 33                                    0.0
# 34                                    0.2
# 35                                    0.3
# 36                                    0.3
# 37                                    0.3
#
#     Expenditure on housing & community amenities  ...  Movers Ranking  \
# 0                                            0.7  ...               5
# 1                                            0.2  ...              19
# 2                                            0.4  ...              38
# 3                                            0.6  ...              21
# 4                                            1.0  ...               7
# 5                                            0.5  ...              56
# 6                                            1.1  ...              44
# 7                                            0.5  ...              16
# 8                                            0.2  ...              15
# 9                                            0.9  ...              23
# 10                                           0.5  ...              47
# 11                                           0.3  ...              59
# 12                                           0.8  ...              13
# 13                                           0.3  ...              39
# 14                                           0.3  ...              32
# 15                                           0.2  ...              20
# 16                                           0.4  ...              72
# 17                                           0.5  ...              57
# 18                                           0.4  ...              41
# 19                                           0.3  ...              51
# 20                                           0.6  ...              62
# 21                                           0.5  ...              26
# 22                                           1.1  ...              54
# 23                                           0.6  ...              70
# 24                                           0.3  ...              73
# 25                                           2.3  ...               1
# 26                                           0.9  ...              27
# 27                                           0.6  ...               6
# 28                                           1.2  ...              65
# 29                                           1.9  ...              67
# 30                                           0.4  ...              71
# 31                                           0.9  ...              69
# 32                                           2.5  ...              60
# 33                                           0.8  ...              36
# 34                                           1.4  ...              42
# 35                                           0.7  ...              63
# 36                                           1.5  ...              28
# 37                                           2.7  ...              17
#
#     Open For Business Ranking  Power Ranking  Quality of Life Ranking   GDPPC  \
# 0                          25              7                       14   32477
# 1                           2             13                        7   80215
# 2                          28             19                       18   25832
# 3                          36             17                       21   29847
# 4                           5             22                       20   52889
# 5                           1             30                       13  101450
# 6                          29              6                       16   36248
# 7                          14             15                        5   56328
# 8                          62              8                       46   35330
# 9                          10             23                        4   74735
# 10                          7             20                        3   50273
# 11                         15             27                       11   43439
# 12                         13             29                        8   37809
# 13                          6             21                        6   44433
# 14                          9             35                        9   41921
# 15                         46             43                       26   18036
# 16                         39             73                       44   20713
# 17                         22             41                       17   19223
# 18                         17              4                       10   41219
# 19                          4             26                        2   52002
# 20                         43             56                       24   17231
# 21                         45              1                       15   55837
# 22                         37             67                       29   11536
# 23                         32             42                       22   12494
# 24                         26             72                       45   17295
# 25                         67             11                       25   40438
# 26                         63             16                       37    9130
# 27                          8             49                       28    5816
# 28                         48             65                       38   12500
# 29                         47             68                       35    6820
# 30                         33             70                       47   14172
# 31                         42             71                       49   13665
# 32                         70             34                       68    5740
# 33                         57             45                       69    5496
# 34                         65             36                       67   10508
# 35                         71             28                       71    2115
# 36                         24             40                       32    3346
# 37                         61             32                       56    5692
#
#     Literacy  InfantMortality  Agriculture  Population  NetMigration
# 0      0.990              2.0        0.012   127000000           0.0
# 1      0.990              3.6        0.008     8287000           4.7
# 2      0.981              3.3        0.025    46560000           8.0
# 3      0.992              3.3        0.022    60800000           3.9
# 4      0.968              2.4        0.000     5535000          13.6
# 5      1.000              3.4        0.003      569676          16.3
# 6      0.990              3.3        0.017    66810000           1.1
# 7      0.990              3.2        0.025    23780000           5.6
# 8      0.978              3.5        0.013     8380000           2.2
# 9      1.000              2.5        0.017     5196000           6.6
# 10     0.990              2.6        0.014     9799000           5.4
# 11     0.980              3.4        0.014     8611000           5.2
# 12     0.990              4.5        0.070     4596000           2.2
# 13     0.990              3.6        0.018    16940000           1.9
# 14     1.000              2.5        0.028     5482000           3.0
# 15     0.977              4.6        0.038    10820000           2.3
# 16     0.997              4.0        0.022     2064000           0.4
# 17     0.957              4.4        0.023    10350000           2.6
# 18     0.990              3.4        0.007    81410000           1.5
# 19     0.990              4.0        0.016     5676000           2.1
# 20     0.990              2.6        0.025    10550000           2.2
# 21     0.860              5.8        0.011   321400000           3.9
# 22     0.993              9.5        0.043     4224000          -1.9
# 23     0.998              4.5        0.029    38000000          -0.4
# 24     0.998              3.8        0.034     1312000          -3.2
# 25     0.938             10.3        0.008     9157000          11.3
# 26     0.950             18.2        0.080    78670000          -1.2
# 27     0.967              9.4        0.105    67960000           0.0
# 28     0.988              9.6        0.054    19510000          -0.2
# 29     0.984              8.5        0.053     7178000          -0.3
# 30     0.998              3.8        0.034     2910000          -6.2
# 31     0.999              5.3        0.033     1978000          -6.2
# 32     0.992              3.6        0.086     9513000           0.7
# 33     0.998             24.7        0.047     9651000           0.0
# 34     0.998             20.3        0.045    17540000           0.4
# 35     0.998              8.0        0.095    45200000           0.0
# 36     0.939             23.5        0.137   257600000          -1.2
# 37     0.943             32.0        0.025    54960000          -0.9
#
# [38 rows x 30 columns]

# %%
health2016["2016"] = health2016["2016"].map("{:.2f}".format)
health2016.head()
# Out:
#        Country                           Indicator Name   2016       2017  \
# 0        Japan  Life expectancy at birth, total (years)  83.98  84.099756
# 1  Switzerland  Life expectancy at birth, total (years)  83.60  83.602439
# 2        Spain  Life expectancy at birth, total (years)  83.33  83.329268
# 3        Italy  Life expectancy at birth, total (years)  83.24  83.243902
# 4    Singapore  Life expectancy at birth, total (years)  82.85  82.895122
#
#    Expenditure on general public services  Expenditure on defense  \
# 0                                     3.9                     0.9
# 1                                     4.7                     0.8
# 2                                     5.8                     1.0
# 3                                     7.9                     1.3
# 4                                     1.0                     3.3
#
#    Expenditure on public order & safety  Expenditure on economic affairs  \
# 0                                   1.2                              3.5
# 1                                   1.6                              4.0
# 2                                   1.9                              3.7
# 3                                   1.9                              3.9
# 4                                   1.0                              2.7
#
#    Expenditure on environment protection  \
# 0                                    1.2
# 1                                    0.6
# 2                                    0.8
# 3                                    0.9
# 4                                    0.2
#
#    Expenditure on housing & community amenities  ...  Movers Ranking  \
# 0                                           0.7  ...               5
# 1                                           0.2  ...              19
# 2                                           0.4  ...              38
# 3                                           0.6  ...              21
# 4                                           1.0  ...               7
#
#    Open For Business Ranking  Power Ranking  Quality of Life Ranking  GDPPC  \
# 0                         25              7                       14  32477
# 1                          2             13                        7  80215
# 2                         28             19                       18  25832
# 3                         36             17                       21  29847
# 4                          5             22                       20  52889
#
#    Literacy  InfantMortality  Agriculture  Population  NetMigration
# 0     0.990              2.0        0.012   127000000           0.0
# 1     0.990              3.6        0.008     8287000           4.7
# 2     0.981              3.3        0.025    46560000           8.0
# 3     0.992              3.3        0.022    60800000           3.9
# 4     0.968              2.4        0.000     5535000          13.6
#
# [5 rows x 30 columns]

# %%
reducedhealth_df = health2016.loc[:, ["Country", "2016", "Expenditure on health"]]
reducedhealth_df.head()
# Out:
#        Country   2016  Expenditure on health
# 0        Japan  83.98                    7.6
# 1  Switzerland  83.60                    2.2
# 2        Spain  83.33                    5.9
# 3        Italy  83.24                    6.9
# 4    Singapore  82.85                    2.2

# %%
reducedhealth_df.count()
# Out:
# Country                  38
# 2016                     38
# Expenditure on health    38
# dtype: int64

# %% [markdown]
# ### Data analysis
# ----

# %% [markdown]
# #### Question 1: (Sample) What our developed countries' most prioritized spending?
# Answer here

# %%
# Perform statistical analysis
# Put applicable plot depending on your question
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd

# %%
x_values = reducedhealth_df['2016']
y_values = reducedhealth_df['Expenditure on health']
plt.scatter(x_values,y_values)
plt.xlabel('Total Life Expectancy at Birth (Years)')
plt.ylabel('Percentage of Government Spending')
plt.show()

# %%
x_values.astype(float)
# Out:
# 0     83.98
# 1     83.60
# 2     83.33
# 3     83.24
# 4     82.85
# 5     82.69
# 6     82.52
# 7     82.45
# 8     82.41
# 9     82.41
# 10    82.31
# 11    81.64
# 12    81.61
# 13    81.56
# 14    81.43
# 15    81.39
# 16    81.18
# 17    81.12
# 18    80.99
# 19    80.85
# 20    79.03
# 21    78.54
# 22    78.02
# 23    77.85
# 24    77.64
# 25    77.47
# 26    76.86
# 27    76.40
# 28    75.31
# 29    74.81
# 30    74.67
# 31    74.58
# 32    73.83
# 33    72.49
# 34    72.30
# 35    71.48
# 36    71.03
# 37    63.15
# Name: 2016, dtype: float64

# %%
x_values = reducedhealth_df['2016'].astype(float)
y_values = reducedhealth_df['Expenditure on health']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
# plt.annotate("Hello", (6, 10), fontsize=15,color="red")
plt.xlabel('Total Life Expectancy at Birth (Years)')
plt.ylabel('Percentage of Government Spending')
plt.show()

# %%
new addition

# %%
multi_plot = reducedhealth_df.plot(kind="bar", figsize=(10, 10))
multi_plot.set_xticklabels(reducedhealth_df["Country"])
plt.tight_layout()
plt.show()

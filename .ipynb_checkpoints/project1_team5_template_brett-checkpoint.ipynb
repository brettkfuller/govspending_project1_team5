# %% [markdown]
# # Global Budget Spending Analysis
# ----
# <i> Project 1 Team 5 </i><br/>
# Brett Fuller, Diego Jones, Mav Sanchez

# %%
#Import necessary package dependencies
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
from pprint import pprint
from scipy.stats import linregress
from pandas import DataFrame


#Import API Key
from config import api_key

#Define directories
source_data_dir = "source_data"
staging_data_dir = "staging_data"
target_data_dir = "target_data"
target_images_dir = "target_images"

# %% [markdown]
# ### Data extraction
# ----
# #####            API Calls

# %%
# Define base URLs for API
base_url_fromwherever ="put main endpoint here"

# %%
# Get  data
list_whatever = []
save_to_whatever = []

for a in list_whatever:
    
    query_url = base_url_fromwherever + 'appid=' + api_key + '&param=' + a
    response = requests.get(query_url).json() 
    try:
        list_whatever.append(response) #customize depending on the JSON structure
    except:
        pass

# Save api data to data frames
staging_df = pd.DataFrame(list_whatever)

# %%
# Save df to csv so we don't have to perform API calls again
staging_df.to_csv(f"{staging_data_dir}/staging_df.csv")

# %%
#####            CSV Load

# %%
budget_breakdown = "source_data/budget_breakdown.csv"

budgetbreakdown_df = pd.read_csv(budget_breakdown)
clean_budgetbreakdown = budgetbreakdown_df[['Unnamed: 0', 'Expenditure on general public services',
       'Expenditure on defense', 'Expenditure on public order & safety',
       'Expenditure on economic affairs',
       'Expenditure on environment protection',
       'Expenditure on housing & community amenities', 'Expenditure on health',
       'Expenditure on recreation, culture, & religion',
       'Expenditure on education', 'Expenditure on social protection']]
clean_budgetbreakdown = clean_budgetbreakdown.dropna()

clean_budgetbreakdown = clean_budgetbreakdown.rename(columns = {'Unnamed: 0': 'Country'})

# %%
country_rank = "source_data/top_73.csv"
country_ranking = pd.read_csv(country_rank, header=None
                             )
country_ranking = country_ranking.rename(columns = {0: 'Country'})

combined_countrydf = clean_budgetbreakdown.merge(country_ranking, on='Country')
combined_countrydf.columns = ['Country',
               'Expenditure on general public services',
                               'Expenditure on defense',
                 'Expenditure on public order & safety',
                      'Expenditure on economic affairs',
                'Expenditure on environment protection',
         'Expenditure on housing & community amenities',
                                'Expenditure on health',
       'Expenditure on recreation, culture, & religion',
                             'Expenditure on education',
                     'Expenditure on social protection',
                                                      'Overall Ranking',
                                                      'Entrepreneurship Ranking',
                                                      'Adventure Ranking',
                                                      'Citizenship Ranking',
                                                      'Cultural Influence Ranking',
                                                      'Heritage Ranking',
                                                      'Movers Ranking',
                                                      'Open For Business Ranking',
                                                      'Power Ranking',
                                                     'Quality of Life Ranking']

combined_countrydf
# Out:
#                  Country  Expenditure on general public services  \
# 0                Austria                                     6.4
# 1                Estonia                                     4.0
# 2                Finland                                     8.0
# 3                 France                                     6.2
# 4                Germany                                     5.7
# 5                 Greece                                     8.8
# 6                  Italy                                     7.9
# 7                 Latvia                                     4.4
# 8              Lithuania                                     4.0
# 9             Luxembourg                                     5.0
# 10           Netherlands                                     4.5
# 11              Portugal                                     8.3
# 12              Slovenia                                     6.6
# 13                 Spain                                     5.8
# 14             Australia                                     4.2
# 15        Czech Republic                                     4.2
# 16               Denmark                                     6.3
# 17                Israel                                     3.6
# 18                 Japan                                     3.9
# 19           New Zealand                                     4.2
# 20                Norway                                     4.7
# 21             Singapore                                     1.0
# 22                Sweden                                     6.7
# 23           Switzerland                                     4.7
# 24        United Kingdom                                     4.5
# 25         United States                                     5.7
# 26             Indonesia                                     3.8
# 27               Myanmar                                     2.7
# 28              Thailand                                     7.6
# 29              Bulgaria                                     2.8
# 30               Croatia                                     8.1
# 31                Poland                                     4.7
# 32               Romania                                     4.4
# 33                Turkey                                     4.8
# 34            Azerbaijan                                     4.4
# 35               Belarus                                     3.4
# 36            Kazakhstan                                     1.7
# 37               Ukraine                                     5.6
# 38  United Arab Emirates                                    14.3
# 39          South Africa                                    23.7
#
#     Expenditure on defense  Expenditure on public order & safety  \
# 0                      0.6                                   1.3
# 1                      2.4                                   1.9
# 2                      1.3                                   1.2
# 3                      1.8                                   1.6
# 4                      0.9                                   1.6
# 5                      2.1                                   2.1
# 6                      1.3                                   1.9
# 7                      1.6                                   2.2
# 8                      1.6                                   1.5
# 9                      0.4                                   1.0
# 10                     1.1                                   1.9
# 11                     0.9                                   1.8
# 12                     0.9                                   1.7
# 13                     1.0                                   1.9
# 14                     1.9                                   1.7
# 15                     0.7                                   1.7
# 16                     1.1                                   1.0
# 17                     5.7                                   1.6
# 18                     0.9                                   1.2
# 19                     0.9                                   1.9
# 20                     1.6                                   1.2
# 21                     3.3                                   1.0
# 22                     1.2                                   1.3
# 23                     0.8                                   1.6
# 24                     2.0                                   1.8
# 25                     3.2                                   2.0
# 26                     1.1                                   1.3
# 27                     3.6                                   0.5
# 28                     1.4                                   1.2
# 29                     1.1                                   2.4
# 30                     1.1                                   2.3
# 31                     1.6                                   2.2
# 32                     1.7                                   2.0
# 33                     1.4                                   2.1
# 34                     3.5                                   2.1
# 35                     1.2                                   1.9
# 36                     1.4                                   1.0
# 37                     2.5                                   3.0
# 38                     0.8                                   3.6
# 39                     1.2                                   3.7
#
#     Expenditure on economic affairs  Expenditure on environment protection  \
# 0                               5.7                                    0.4
# 1                               4.2                                    0.6
# 2                               4.5                                    0.2
# 3                               5.5                                    0.9
# 4                               3.3                                    0.6
# 5                               4.1                                    1.4
# 6                               3.9                                    0.9
# 7                               4.7                                    0.5
# 8                               3.0                                    0.5
# 9                               5.7                                    0.8
# 10                              3.9                                    1.4
# 11                              3.2                                    0.6
# 12                              4.6                                    0.6
# 13                              3.7                                    0.8
# 14                              4.0                                    0.8
# 15                              5.9                                    0.7
# 16                              3.3                                    0.4
# 17                              2.2                                    0.6
# 18                              3.5                                    1.2
# 19                              3.0                                    0.9
# 20                              5.4                                    0.9
# 21                              2.7                                    0.2
# 22                              4.2                                    0.4
# 23                              4.0                                    0.6
# 24                              3.0                                    0.7
# 25                              3.4                                    0.0
# 26                              2.3                                    0.3
# 27                              9.9                                    0.0
# 28                              2.3                                    0.0
# 29                              4.1                                    0.6
# 30                              5.9                                    0.6
# 31                              4.4                                    0.4
# 32                              4.8                                    0.6
# 33                              4.1                                    0.4
# 34                              8.8                                    0.0
# 35                              5.0                                    0.1
# 36                              1.7                                    0.2
# 37                              2.5                                    0.3
# 38                              4.9                                    0.7
# 39                              6.6                                    0.3
#
#     Expenditure on housing & community amenities  Expenditure on health  \
# 0                                            0.3                    8.2
# 1                                            0.3                    5.2
# 2                                            0.3                    7.2
# 3                                            1.1                    8.1
# 4                                            0.4                    7.2
# 5                                            0.2                    5.0
# 6                                            0.6                    6.9
# 7                                            0.9                    3.8
# 8                                            0.4                    5.8
# 9                                            0.5                    4.8
# 10                                           0.3                    7.5
# 11                                           0.5                    6.1
# 12                                           0.4                    6.7
# 13                                           0.4                    5.9
# 14                                           0.5                    6.9
# 15                                           0.6                    7.4
# 16                                           0.3                    8.5
# 17                                           0.2                    5.1
# 18                                           0.7                    7.6
# 19                                           0.8                    6.6
# 20                                           0.9                    8.8
# 21                                           1.0                    2.2
# 22                                           0.5                    6.9
# 23                                           0.2                    2.2
# 24                                           0.6                    7.6
# 25                                           0.5                    9.3
# 26                                           1.5                    1.5
# 27                                           0.5                    0.9
# 28                                           0.6                    1.1
# 29                                           1.9                    5.0
# 30                                           1.1                    6.4
# 31                                           0.6                    4.6
# 32                                           1.2                    4.0
# 33                                           0.9                    5.5
# 34                                           0.8                    1.2
# 35                                           2.5                    4.9
# 36                                           1.4                    3.8
# 37                                           0.7                    3.2
# 38                                           2.3                    2.8
# 39                                           2.7                    5.1
#
#     Expenditure on recreation, culture, & religion  Expenditure on education  \
# 0                                              1.2                       4.9
# 1                                              2.0                       5.7
# 2                                              1.4                       6.1
# 3                                              1.4                       5.5
# 4                                              1.0                       4.1
# 5                                              0.7                       4.0
# 6                                              0.8                       3.8
# 7                                              1.4                       5.5
# 8                                              1.0                       5.1
# 9                                              1.2                       4.6
# 10                                             1.2                       5.2
# 11                                             0.9                       4.8
# 12                                             1.4                       5.5
# 13                                             1.1                       4.0
# 14                                             0.8                       5.4
# 15                                             1.3                       4.5
# 16                                             1.7                       6.8
# 17                                             1.4                       6.9
# 18                                             0.4                       3.2
# 19                                             0.9                       5.9
# 20                                             1.6                       5.7
# 21                                             0.5                       2.9
# 22                                             1.3                       6.6
# 23                                             0.8                       5.1
# 24                                             0.6                       4.8
# 25                                             0.3                       6.1
# 26                                             0.2                       3.6
# 27                                             0.2                       2.0
# 28                                             0.3                       3.6
# 29                                             1.0                       3.4
# 30                                             1.8                       4.8
# 31                                             1.1                       5.0
# 32                                             0.9                       3.3
# 33                                             0.8                       3.9
# 34                                             1.2                       3.1
# 35                                             1.3                       5.5
# 36                                             0.8                       4.0
# 37                                             0.7                       5.4
# 38                                             0.6                       1.7
# 39                                             1.0                       8.3
#
#     ...  Overall Ranking  Entrepreneurship Ranking  Adventure Ranking  \
# 0   ...               18                        17                 22
# 1   ...               55                        40                 60
# 2   ...               14                        16                 27
# 3   ...               12                        15                 12
# 4   ...                4                         1                 50
# 5   ...               27                        32                  4
# 6   ...               17                        20                  2
# 7   ...               62                        48                 59
# 8   ...               59                        47                 61
# 9   ...               21                        19                 45
# 10  ...                9                        10                 13
# 11  ...               24                        25                  6
# 12  ...               56                        41                 51
# 13  ...               19                        21                  3
# 14  ...                5                         9                 10
# 15  ...               37                        29                 41
# 16  ...               13                        14                 30
# 17  ...               29                        24                 69
# 18  ...                3                         2                 34
# 19  ...               11                        18                  7
# 20  ...               10                        13                 23
# 21  ...               16                        12                 25
# 22  ...                8                         7                 20
# 23  ...                1                         5                 14
# 24  ...                6                         4                 36
# 25  ...                7                         3                 33
# 26  ...               41                        44                 35
# 27  ...               57                        69                 62
# 28  ...               26                        36                  5
# 29  ...               58                        54                 52
# 30  ...               44                        37                 19
# 31  ...               34                        26                 42
# 32  ...               54                        53                 44
# 33  ...               35                        31                 21
# 34  ...               61                        64                 66
# 35  ...               70                        50                 58
# 36  ...               66                        71                 70
# 37  ...               68                        45                 46
# 38  ...               22                        23                 63
# 39  ...               39                        35                 26
#
#     Citizenship Ranking  Cultural Influence Ranking  Heritage Ranking  \
# 0                    12                          25                20
# 1                    26                          61                62
# 2                     6                          26                43
# 3                    13                           2                 4
# 4                    10                          15                19
# 5                    23                          13                 3
# 6                    18                           1                 1
# 7                    33                          68                68
# 8                    35                          70                64
# 9                    14                          27                55
# 10                    4                          12                24
# 11                   19                          23                 8
# 12                   29                          60                58
# 13                   16                           3                 2
# 14                    8                           8                27
# 15                   22                          48                34
# 16                    5                          19                41
# 17                   32                          44                28
# 18                   17                           6                10
# 19                    9                          17                37
# 20                    3                          21                48
# 21                   21                           9                22
# 22                    1                          14                33
# 23                    7                          10                31
# 24                   11                           5                12
# 25                   15                           4                18
# 26                   59                          43                29
# 27                   73                          66                66
# 28                   46                          18                 9
# 29                   36                          64                53
# 30                   25                          34                35
# 31                   20                          47                25
# 32                   40                          50                38
# 33                   43                          29                 7
# 34                   60                          69                69
# 35                   56                          67                67
# 36                   70                          72                70
# 37                   49                          56                51
# 38                   38                          22                63
# 39                   37                          37                26
#
#     Movers Ranking  Open For Business Ranking  Power Ranking  \
# 0               59                         15             27
# 1               73                         26             72
# 2               32                          9             35
# 3               44                         29              6
# 4               41                         17              4
# 5               20                         46             43
# 6               21                         36             17
# 7               69                         42             71
# 8               71                         33             70
# 9               56                          1             30
# 10              39                          6             21
# 11              57                         22             41
# 12              72                         39             73
# 13              38                         28             19
# 14              16                         14             15
# 15              62                         43             56
# 16              51                          4             26
# 17              15                         62              8
# 18               5                         25              7
# 19              13                         13             29
# 20              23                         10             23
# 21               7                          5             22
# 22              47                          7             20
# 23              19                          2             13
# 24              49                         27              5
# 25              26                         45              1
# 26              28                         24             40
# 27              33                         54             47
# 28               6                          8             49
# 29              67                         47             68
# 30              54                         37             67
# 31              70                         32             42
# 32              65                         48             65
# 33              27                         63             16
# 34              36                         57             45
# 35              60                         70             34
# 36              42                         65             36
# 37              63                         71             28
# 38               1                         67             11
# 39              17                         61             32
#
#     Quality of Life Ranking
# 0                        11
# 1                        45
# 2                         9
# 3                        16
# 4                        10
# 5                        26
# 6                        21
# 7                        49
# 8                        47
# 9                        13
# 10                        6
# 11                       17
# 12                       44
# 13                       18
# 14                        5
# 15                       24
# 16                        2
# 17                       46
# 18                       14
# 19                        8
# 20                        4
# 21                       20
# 22                        3
# 23                        7
# 24                       12
# 25                       15
# 26                       32
# 27                       62
# 28                       28
# 29                       35
# 30                       29
# 31                       22
# 32                       38
# 33                       37
# 34                       69
# 35                       68
# 36                       67
# 37                       71
# 38                       25
# 39                       56
#
# [40 rows x 21 columns]

# %%
population_breakdown = "source_data/Countries.csv"

populationbreakdown_df = pd.read_csv(population_breakdown)
populationbreakdown_df.columns


doublecombined_countrydf = combined_countrydf.merge(populationbreakdown_df, on='Country')
doublecombined_countrydf.head()
# Out:
#    Country  Expenditure on general public services  Expenditure on defense  \
# 0  Austria                                     6.4                     0.6
# 1  Estonia                                     4.0                     2.4
# 2  Finland                                     8.0                     1.3
# 3   France                                     6.2                     1.8
# 4  Germany                                     5.7                     0.9
#
#    Expenditure on public order & safety  Expenditure on economic affairs  \
# 0                                   1.3                              5.7
# 1                                   1.9                              4.2
# 2                                   1.2                              4.5
# 3                                   1.6                              5.5
# 4                                   1.6                              3.3
#
#    Expenditure on environment protection  \
# 0                                    0.4
# 1                                    0.6
# 2                                    0.2
# 3                                    0.9
# 4                                    0.6
#
#    Expenditure on housing & community amenities  Expenditure on health  \
# 0                                           0.3                    8.2
# 1                                           0.3                    5.2
# 2                                           0.3                    7.2
# 3                                           1.1                    8.1
# 4                                           0.4                    7.2
#
#    Expenditure on recreation, culture, & religion  Expenditure on education  \
# 0                                             1.2                       4.9
# 1                                             2.0                       5.7
# 2                                             1.4                       6.1
# 3                                             1.4                       5.5
# 4                                             1.0                       4.1
#
#    ...  Movers Ranking  Open For Business Ranking  Power Ranking  \
# 0  ...              59                         15             27
# 1  ...              73                         26             72
# 2  ...              32                          9             35
# 3  ...              44                         29              6
# 4  ...              41                         17              4
#
#    Quality of Life Ranking  GDPPC  Literacy  InfantMortality  Agriculture  \
# 0                       11  43439     0.980              3.4        0.014
# 1                       45  17295     0.998              3.8        0.034
# 2                        9  41921     1.000              2.5        0.028
# 3                       16  36248     0.990              3.3        0.017
# 4                       10  41219     0.990              3.4        0.007
#
#    Population  NetMigration
# 0     8611000           5.2
# 1     1312000          -3.2
# 2     5482000           3.0
# 3    66810000           1.1
# 4    81410000           1.5
#
# [5 rows x 27 columns]

# %%
# Load raw CSV files to data frame
safety_rank_data = pd.read_csv(f"{source_data_dir}/safety.csv")
safety_rank_data.head()
# Out:
#    Rank      Country  Amount spent on Public Safety (in Billions)
# 0     1  Netherlands                                       193.40
# 1     2       Norway                                        89.84
# 2     3    Australia                                          NaN
# 3     4       Sweden                                          NaN
# 4     5       Canada                                          NaN

# %%
health_rank_data = pd.read_csv(f"{source_data_dir}/health.csv")
health_rank_data.head()
# Out:
#                 Country                           Indicator Name       2016  \
# 0  Hong Kong SAR, China  Life expectancy at birth, total (years)  84.226829
# 1                 Japan  Life expectancy at birth, total (years)  83.984878
# 2      Macao SAR, China  Life expectancy at birth, total (years)  83.854000
# 3           Switzerland  Life expectancy at birth, total (years)  83.602439
# 4                 Spain  Life expectancy at birth, total (years)  83.329268
#
#         2017
# 0  84.680488
# 1  84.099756
# 2  83.989000
# 3  83.602439
# 4  83.329268

# %% [markdown]
# ### Data cleansing
# ----

# %%
# Options
# Delete nulls
# FillNA with zero, etc
# Reformat data (date format, name format)
# Save only the columns you need
from pandas import DataFrame

# %%
safety2016 = pd.merge(safety_rank_data, doublecombined_countrydf, on="Country")
safety2016.head()
# Out:
#    Rank      Country  Amount spent on Public Safety (in Billions)  \
# 0     1  Netherlands                                       193.40
# 1     2       Norway                                        89.84
# 2     3    Australia                                          NaN
# 3     4       Sweden                                          NaN
# 4     6   Luxembourg                                          NaN
#
#    Expenditure on general public services  Expenditure on defense  \
# 0                                     4.5                     1.1
# 1                                     4.7                     1.6
# 2                                     4.2                     1.9
# 3                                     6.7                     1.2
# 4                                     5.0                     0.4
#
#    Expenditure on public order & safety  Expenditure on economic affairs  \
# 0                                   1.9                              3.9
# 1                                   1.2                              5.4
# 2                                   1.7                              4.0
# 3                                   1.3                              4.2
# 4                                   1.0                              5.7
#
#    Expenditure on environment protection  \
# 0                                    1.4
# 1                                    0.9
# 2                                    0.8
# 3                                    0.4
# 4                                    0.8
#
#    Expenditure on housing & community amenities  Expenditure on health  ...  \
# 0                                           0.3                    7.5  ...
# 1                                           0.9                    8.8  ...
# 2                                           0.5                    6.9  ...
# 3                                           0.5                    6.9  ...
# 4                                           0.5                    4.8  ...
#
#    Movers Ranking  Open For Business Ranking  Power Ranking  \
# 0              39                          6             21
# 1              23                         10             23
# 2              16                         14             15
# 3              47                          7             20
# 4              56                          1             30
#
#    Quality of Life Ranking   GDPPC  Literacy  InfantMortality  Agriculture  \
# 0                        6   44433      0.99              3.6        0.018
# 1                        4   74735      1.00              2.5        0.017
# 2                        5   56328      0.99              3.2        0.025
# 3                        3   50273      0.99              2.6        0.014
# 4                       13  101450      1.00              3.4        0.003
#
#    Population  NetMigration
# 0    16940000           1.9
# 1     5196000           6.6
# 2    23780000           5.6
# 3     9799000           5.4
# 4      569676          16.3
#
# [5 rows x 29 columns]

# %%
reducedsafety_df = safety2016.loc[:, ["Country", "Rank", "Expenditure on public order & safety"]]
reducedsafety_df
# Out:
#            Country  Rank  Expenditure on public order & safety
# 0      Netherlands     1                                   1.9
# 1           Norway     2                                   1.2
# 2        Australia     3                                   1.7
# 3           Sweden     4                                   1.3
# 4       Luxembourg     6                                   1.0
# 5      New Zealand     7                                   1.9
# 6      Switzerland     8                                   1.6
# 7          Denmark     9                                   1.0
# 8        Singapore    12                                   1.0
# 9           Israel    13                                   1.6
# 10         Finland    14                                   1.2
# 11         Germany    16                                   1.6
# 12         Austria    17                                   1.3
# 13          France    18                                   1.6
# 14           Japan    19                                   1.2
# 15        Slovenia    23                                   1.7
# 16        Portugal    24                                   1.8
# 17           Spain    25                                   1.9
# 18           Italy    26                                   1.9
# 19  Czech Republic    28                                   1.7
# 20         Estonia    31                                   1.9
# 21          Greece    32                                   2.1
# 22         Croatia    34                                   2.3
# 23          Poland    35                                   2.2
# 24          Latvia    36                                   2.2
# 25          Turkey    38                                   2.1
# 26       Lithuania    39                                   1.5

# %%
reducedsafety_df.count()
# Out:
# Country                                 27
# Rank                                    27
# Expenditure on public order & safety    27
# dtype: int64

# %%
health2016 = pd.merge(health_rank_data, doublecombined_countrydf, on="Country")
health2016.head()
# Out:
#        Country                           Indicator Name       2016       2017  \
# 0        Japan  Life expectancy at birth, total (years)  83.984878  84.099756
# 1  Switzerland  Life expectancy at birth, total (years)  83.602439  83.602439
# 2        Spain  Life expectancy at birth, total (years)  83.329268  83.329268
# 3        Italy  Life expectancy at birth, total (years)  83.243902  83.243902
# 4    Singapore  Life expectancy at birth, total (years)  82.846341  82.895122
#
#    Expenditure on general public services  Expenditure on defense  \
# 0                                     3.9                     0.9
# 1                                     4.7                     0.8
# 2                                     5.8                     1.0
# 3                                     7.9                     1.3
# 4                                     1.0                     3.3
#
#    Expenditure on public order & safety  Expenditure on economic affairs  \
# 0                                   1.2                              3.5
# 1                                   1.6                              4.0
# 2                                   1.9                              3.7
# 3                                   1.9                              3.9
# 4                                   1.0                              2.7
#
#    Expenditure on environment protection  \
# 0                                    1.2
# 1                                    0.6
# 2                                    0.8
# 3                                    0.9
# 4                                    0.2
#
#    Expenditure on housing & community amenities  ...  Movers Ranking  \
# 0                                           0.7  ...               5
# 1                                           0.2  ...              19
# 2                                           0.4  ...              38
# 3                                           0.6  ...              21
# 4                                           1.0  ...               7
#
#    Open For Business Ranking  Power Ranking  Quality of Life Ranking  GDPPC  \
# 0                         25              7                       14  32477
# 1                          2             13                        7  80215
# 2                         28             19                       18  25832
# 3                         36             17                       21  29847
# 4                          5             22                       20  52889
#
#    Literacy  InfantMortality  Agriculture  Population  NetMigration
# 0     0.990              2.0        0.012   127000000           0.0
# 1     0.990              3.6        0.008     8287000           4.7
# 2     0.981              3.3        0.025    46560000           8.0
# 3     0.992              3.3        0.022    60800000           3.9
# 4     0.968              2.4        0.000     5535000          13.6
#
# [5 rows x 30 columns]

# %%
health2016["2016"] = health2016["2016"].map("{:.2f}".format)
health2016.head()
# Out:
#        Country                           Indicator Name   2016       2017  \
# 0        Japan  Life expectancy at birth, total (years)  83.98  84.099756
# 1  Switzerland  Life expectancy at birth, total (years)  83.60  83.602439
# 2        Spain  Life expectancy at birth, total (years)  83.33  83.329268
# 3        Italy  Life expectancy at birth, total (years)  83.24  83.243902
# 4    Singapore  Life expectancy at birth, total (years)  82.85  82.895122
#
#    Expenditure on general public services  Expenditure on defense  \
# 0                                     3.9                     0.9
# 1                                     4.7                     0.8
# 2                                     5.8                     1.0
# 3                                     7.9                     1.3
# 4                                     1.0                     3.3
#
#    Expenditure on public order & safety  Expenditure on economic affairs  \
# 0                                   1.2                              3.5
# 1                                   1.6                              4.0
# 2                                   1.9                              3.7
# 3                                   1.9                              3.9
# 4                                   1.0                              2.7
#
#    Expenditure on environment protection  \
# 0                                    1.2
# 1                                    0.6
# 2                                    0.8
# 3                                    0.9
# 4                                    0.2
#
#    Expenditure on housing & community amenities  ...  Movers Ranking  \
# 0                                           0.7  ...               5
# 1                                           0.2  ...              19
# 2                                           0.4  ...              38
# 3                                           0.6  ...              21
# 4                                           1.0  ...               7
#
#    Open For Business Ranking  Power Ranking  Quality of Life Ranking  GDPPC  \
# 0                         25              7                       14  32477
# 1                          2             13                        7  80215
# 2                         28             19                       18  25832
# 3                         36             17                       21  29847
# 4                          5             22                       20  52889
#
#    Literacy  InfantMortality  Agriculture  Population  NetMigration
# 0     0.990              2.0        0.012   127000000           0.0
# 1     0.990              3.6        0.008     8287000           4.7
# 2     0.981              3.3        0.025    46560000           8.0
# 3     0.992              3.3        0.022    60800000           3.9
# 4     0.968              2.4        0.000     5535000          13.6
#
# [5 rows x 30 columns]

# %%
reducedhealth_df = health2016.loc[:, ["Country", "2016", "Expenditure on health"]]
reducedhealth_df.head()
# Out:
#        Country   2016  Expenditure on health
# 0        Japan  83.98                    7.6
# 1  Switzerland  83.60                    2.2
# 2        Spain  83.33                    5.9
# 3        Italy  83.24                    6.9
# 4    Singapore  82.85                    2.2

# %%
reducedhealth_df.count()
# Out:
# Country                  38
# 2016                     38
# Expenditure on health    38
# dtype: int64

# %% [markdown]
# ### Data analysis
# ----

# %% [markdown]
# ### Safety Data

# %%
# Perform statistical analysis
# Put applicable plot depending on your question
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd
import scipy.stats as st

# %%
x_values = reducedsafety_df['Expenditure on public order & safety']
y_values = reducedsafety_df['Rank']
plt.scatter(x_values,y_values)
plt.xlabel('Percentage of Government Spending')
plt.ylabel('Country Rank')
plt.show()

# %%
x_values = reducedsafety_df['Expenditure on public order & safety']
y_values = reducedsafety_df['Rank']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope, 2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (1, 30), fontsize=15,color="red")
plt.xlabel('Percentage of Government Spending')
plt.ylabel('Country Rank')
plt.title('Correlation Between Safety Rank and Safety Spending')
plt.savefig("Safety.png")
plt.show()

# %%
rvalue
# Out:
# 0.6146164023499968

# %%
line_eq = f"y = {round(slope, 2)}x + {round(intercept,2)}"
line_eq
# Out:
# 'y = 19.12x + -12.19'

# %% [markdown]
# The plot above shows a negative correlation between the percentage of a countrie's expenditure on public safety and it's global safety ranking. The opposite is actually displayed - the lower a country was ranked on the UL Public Safety Index, the higher the percentage of it's safety spending. The r-value of .61 means this is a moderatley strong correlation.

# %% [markdown]
# ## Health Data

# %%
x_values = reducedhealth_df['Expenditure on health']
y_values = reducedhealth_df['2016']
plt.scatter(x_values,y_values)
plt.xlabel('Percentage of Government Spending')
plt.ylabel('Total Life Expectancy at Birth (Years)')
plt.show()

# %%
x_values.astype(float)
# Out:
# 0     7.6
# 1     2.2
# 2     5.9
# 3     6.9
# 4     2.2
# 5     4.8
# 6     8.1
# 7     6.9
# 8     5.1
# 9     8.8
# 10    6.9
# 11    8.2
# 12    6.6
# 13    7.5
# 14    7.2
# 15    5.0
# 16    6.7
# 17    6.1
# 18    7.2
# 19    8.5
# 20    7.4
# 21    9.3
# 22    6.4
# 23    4.6
# 24    5.2
# 25    2.8
# 26    5.5
# 27    1.1
# 28    4.0
# 29    5.0
# 30    5.8
# 31    3.8
# 32    4.9
# 33    1.2
# 34    3.8
# 35    3.2
# 36    1.5
# 37    5.1
# Name: Expenditure on health, dtype: float64

# %%
x_values = reducedhealth_df['Expenditure on health']
y_values = reducedhealth_df['2016'].astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope, 2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (2, 65), fontsize=15,color="red")
plt.xlabel('Percentage of Government Spending')
plt.ylabel('Total Life Expectancy at Birth (Years)')
plt.title('Correlation Between Citizen Lifespan and Government Health Budget')
plt.savefig("Health.png")
plt.show()

# %%
yearslived = np.longdouble(reducedhealth_df.iloc[:,1])
moneyspent = np.longdouble(reducedhealth_df.iloc[:,2])
correlation = st.pearsonr(yearslived,moneyspent)
print(f"The correlation between both factors is {round(correlation[0], 2)}")
# Out:
# The correlation between both factors is 0.47

# %% [markdown]
# The plot above shows a positive correlation between the percentage of a countries' expenditure on healthcare and the total life expectancy of its citizens. However, the r-value is only 0.47, showing that the correlation is on the weaker side. From the data we can determine that citizens in countries with higher GDP expenses allocated to healthcare tend to live longer.
